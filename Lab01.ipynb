# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#   F1 INTEREST RATES AND YIELDS – MONEY MARKET                Unnamed: 1  \
# 0                                       Title          Cash Rate Target
# 1                                 Description  Cash Rate Target on date
# 2                                   Frequency                     Daily
# 3                                        Type                  Original
# 4                                       Units                  Per cent
#
#                                           Unnamed: 2  \
# 0                    Change in the Cash Rate Target
# 1  Change in the Cash Rate Target (in percentage ...
# 2                                       as announced
# 3                                           Original
# 4                                           Per cent
#
#                               Unnamed: 3  \
# 0          Interbank Overnight Cash Rate
# 1  Interbank Overnight Cash Rate on date
# 2                                  Daily
# ...

# %%
df.tail()
# Out:
#      F1 INTEREST RATES AND YIELDS – MONEY MARKET Unnamed: 1 Unnamed: 2  \
# 3485                                         NaN        NaN        NaN
# 3486                                         NaN        NaN        NaN
# 3487                                         NaN        NaN        NaN
# 3488                                         NaN        NaN        NaN
# 3489                                         NaN        NaN        NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 3485        NaN        NaN        NaN        NaN        NaN        NaN
# 3486        NaN        NaN        NaN        NaN        NaN        NaN
# 3487        NaN        NaN        NaN        NaN        NaN        NaN
# 3488        NaN        NaN        NaN        NaN        NaN        NaN
# 3489        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...
